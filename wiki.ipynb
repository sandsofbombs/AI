# %% [markdown]
#  # What is the average number of references included in Wikipedia science articles?

# %%
import numpy as np
import scipy.stats as stats

# Example sample data: number of references in 10 Wikipedia science articles
references = [42, 38, 55, 47, 60, 52, 49, 58, 45, 50]

# Calculate sample statistics
mean = np.mean(references)
std_dev = np.std(references, ddof=1)
n = len(references)

# 95% confidence interval for the mean
confidence = 0.95
alpha = 1 - confidence
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)
margin_of_error = t_critical * (std_dev / np.sqrt(n))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample mean: 49.60
# 95% Confidence Interval: (44.63, 54.57)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Example sample data: number of references in 10 Wikipedia science articles
references = [42, 38, 55, 47, 60, 52, 49, 58, 45, 50]

# Calculate sample statistics
mean = np.mean(references)
std_dev = np.std(references, ddof=1)
n = len(references)

# 95% confidence interval for the mean
confidence = 0.95
alpha = 1 - confidence
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)
margin_of_error = t_critical * (std_dev / np.sqrt(n))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(references, bins=6, color='skyblue', edgecolor='black')
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean = {mean:.2f}')
plt.axvline(lower_bound, color='green', linestyle='dotted', linewidth=2, label=f'Lower CI = {lower_bound:.2f}')
plt.axvline(upper_bound, color='green', linestyle='dotted', linewidth=2, label=f'Upper CI = {upper_bound:.2f}')
plt.title('Histogram of References in Wikipedia Science Articles')
plt.xlabel('Number of References')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Sample mean: 49.60
# 95% Confidence Interval: (44.63, 54.57)
